# %%
import pandas as pd
import numpy as np

# %%
results = pd.DataFrame({
    'Model': [
        'Linear Regression',
        'Ridge Regression',
        'Lasso Regression',
        'Support Vector Regression',
        'Random Forest Regression',
        'XGBoost Regression',
        'Voting Regressor'
    ],

    'CV_R2': [
        0.7714,
        0.7715,
        0.7716,
        0.8798,
        0.9162,     
        0.9101,
        0.9265
    ],

    'Train_R2': [
        0.7726,
        0.7725,
        0.7726,
        0.9508,
        0.9870,
        0.9717,
        0.9756
    ],

    'Test_R2': [
        0.7844,
        0.7842,
        0.7845,
        0.8985,
        0.9178,
        0.9083,
        0.9195
    ],

    'Test_MAE': [
        0.4865,
        0.4874,
        0.4864,
        0.2931,
        0.2768,
        0.2975,
        0.2712
    ],

    'Test_RMSE': [
        0.6203,
        0.6205,
        0.6201,
        0.4256,
        0.3830,
        0.4045,
        0.3790
    ]
})

# %%
results
# Out:
#                        Model   CV_R2  Train_R2  Test_R2  Test_MAE  Test_RMSE
# 0          Linear Regression  0.7714    0.7726   0.7844    0.4865     0.6203
# 1           Ridge Regression  0.7715    0.7725   0.7842    0.4874     0.6205
# 2           Lasso Regression  0.7716    0.7726   0.7845    0.4864     0.6201
# 3  Support Vector Regression  0.8798    0.9508   0.8985    0.2931     0.4256
# 4   Random Forest Regression  0.9162    0.9870   0.9178    0.2768     0.3830
# 5         XGBoost Regression  0.9101    0.9717   0.9083    0.2975     0.4045
# 6           Voting Regressor  0.9265    0.9756   0.9195    0.2712     0.3790

# %%
results.style \
    .highlight_max(
    axis=0,
    props = 'color:green',
    subset=['CV_R2','Train_R2','Test_R2']    
    ) \
    .highlight_min(
    axis=0,
    props = 'color:green',
    subset=['Test_MAE','Test_RMSE']    
    )
# Out:
# <style type="text/css">
# #T_f28ae_row4_col2, #T_f28ae_row6_col1, #T_f28ae_row6_col3, #T_f28ae_row6_col4, #T_f28ae_row6_col5 {
#   color: green;
# }
# </style>
# <table id="T_f28ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f28ae_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f28ae_level0_col1" class="col_heading level0 col1" >CV_R2</th>
#       <th id="T_f28ae_level0_col2" class="col_heading level0 col2" >Train_R2</th>
#       <th id="T_f28ae_level0_col3" class="col_heading level0 col3" >Test_R2</th>
#       <th id="T_f28ae_level0_col4" class="col_heading level0 col4" >Test_MAE</th>
#       <th id="T_f28ae_level0_col5" class="col_heading level0 col5" >Test_RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f28ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f28ae_row0_col0" class="data row0 col0" >Linear Regression</td>
# ...
